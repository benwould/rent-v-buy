# %%
#COLUMNS NEEDED IN FINAL DATAFRAME?
#USING REDFIN CSV!

#MEDIAN RENT BY CITY
#RENTAL FORECAST/TRENDS FOR CITY
#MEDIAN RENT BY MONTH AND REGION
#MEDIAN HOME VALUES BY

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import questionary
import matplotlib

# %%
main_df = pd.read_csv(Path('C:/users/ajcth/documents/github/rent-v-buy/redfin_table.csv'), on_bad_lines='skip')
main_df
# Out:
#                 Region\tMonth\tFor-Sale Property Type\tAverage Monthly Rent\tAverage Rent YoY\tMonthly mortgage  \
# Anaheim                     CA\tFebruary 2021\tAll Residential\t$3
# Anaheim                         CA\tFebruary 2021\tCondo/Co-op\t$3
# Anaheim           CA\tFebruary 2021\tSingle Family Residential\t$3
# Anaheim                           CA\tFebruary 2021\tTownhouse\t$3
# Anaheim                        CA\tMarch 2021\tAll Residential\t$3
# ...                                                            ...
# West Palm Beach                 FL\tJune 2022\tAll Residential\t$3
# West Palm Beach                     FL\tJune 2022\tCondo/Co-op\t$3
# West Palm Beach         FL\tJune 2022\tMulti-Family (2-4 Unit)\t$3
# West Palm Beach       FL\tJune 2022\tSingle Family Residential\t$3
# West Palm Beach                       FL\tJune 2022\tTownhouse\t$3
#
#                  5% down\tMonthly mortgage  5% down YoY\tMonthly mortgage  \
# ...
